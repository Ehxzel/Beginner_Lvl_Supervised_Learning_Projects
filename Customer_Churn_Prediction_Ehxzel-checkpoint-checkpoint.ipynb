# %%
#Creating a Classifier to perdict Customer Churn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import numpy as np
import pandas as pd

#loading dataset
house_df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")


#Calling the right columns
# We can't make use of ordinary label encoding for InternetService. We need to use One-Hot Encoding as LE cannot handle sub-categorical values.
house_columns =["Churn"]
#load label encoder
le = LabelEncoder()
#Label encoder and DataType Converter looping through our container
for col in house_columns:
    house_df[col] = le.fit_transform(house_df[col].astype(str))
    house_df[col] = house_df[col].apply(pd.to_numeric)
    
morph =  house_df[col]
print(morph.dtypes)

# Load One-Hot Encoding
internetServ = house_df = ['InternetService']
ohe = OneHotEncoder()
#Fit and Tansform the Data
InternetServ_encoded = ohe.fit_transform(internetServ).toarray()
InternetServ_encoded_float = InternetServ_encoded.astype('float64')
#Get feature names
feature_names = ohe.get_feature_names_out()

#Lets Create a new DataFrame with the encoded data
house_df_encoded = pd.DataFrame(InternetServ_encoded_float, columns = feature_names)
# Next we concatenate the encoded with the original DataFrame
house_df = pd.concat([house_df, house_df_encoded], axis = 1)




# encoded_cols = ohe.get_feature_names_out()
# house_df_encoded = pd.DataFrame(InternetServ.toarray(), columns = encoded_cols)
# house_df = pd.concat([house_df, house_df_encoded], axis = 1)

X = house_df[['MonthlyCharges',]]
y = house_df[['Churn']].values
# #Apparently we need to reshape y array
x = x.reshape(-1,1)
print(X.shape, y.shape)


# house_df = pd.concat([house_df,pd.DataFrame(InternetServ.toarray(),columns = ohe.get_feature_names())], axis = 1)
# print(house_df.info())


#Creating a loop for  converting multiple Columns

# Entry= ['InternetService']
# conv = (input("How many Columns do you want to convert: "))
# for i in conv:  # write the function to perform the operation on the list of columns
#     # entry = input(f"Enter Column(s) name#{i+1}: ")
#     EntryList.append(entry)

# print(EntryList)
# # printing all the Columns in the DataSet
# #cols = realEs.columns.tolist()
# #print(cols)
# '''AVAILABLE COLUMNS['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 
#  'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']'''

# real[EntryList] = real[EntryList].apply(pd.to_numeric)
# morph = real[EntryList]
# print(morph.dtypes)


#Instantiating KNN model
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X,y)
# print(house_df.info())
# Out:
# int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 28
#      26 ohe = OneHotEncoder()
#      27 #Fit and Tansform the Data
# ---> 28 InternetServ_encoded = ohe.fit_transform(internetServ).toarray()
#      29 InternetServ_encoded_float = InternetServ_encoded.astype('float64')
#      30 #Get feature names
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import numpy as np
import pandas as pd

# Load dataset
house_df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Label encode the 'Churn' column
le = LabelEncoder()
house_df['Churn'] = le.fit_transform(house_df['Churn'].astype(str))
house_df['Churn'] = house_df['Churn'].apply(pd.to_numeric)

# One-Hot encode the 'InternetService' column
internetServ = house_df[['InternetService']]
ohe = OneHotEncoder()
InternetServ_encoded = ohe.fit_transform(internetServ).toarray()
feature_names = ohe.get_feature_names_out()

# Create a new DataFrame with the encoded data and concatenate it with the original DataFrame
InternetServ_encoded_float = InternetServ_encoded.astype('float64')
house_df_encoded = pd.DataFrame(InternetServ_encoded_float, columns=feature_names)
house_df = pd.concat([house_df, house_df_encoded], axis=1)

# Select features and labels
X = house_df[['MonthlyCharges'] + list(feature_names)]
y = house_df[['Churn']].values
y = y.reshape(-1, 1)

# Instantiate and fit the KNN model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)

print(house_df.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingMovies  \
# 0  No phone service             DSL             No  ...              No
# 1                No             DSL            Yes  ...              No
# 2                No             DSL            Yes  ...              No
# 3  No phone service             DSL            Yes  ...              No
# 4                No     Fiber optic             No  ...              No
#
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np
import pandas as pd

# Load dataset
house_df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Handle missing values
house_df = house_df.fillna(house_df.mode().iloc[0])

# Label encode the 'Churn' column
le = LabelEncoder()
house_df['Churn'] = le.fit_transform(house_df['Churn'].astype(str))
house_df['Churn'] = house_df['Churn'].apply(pd.to_numeric)

# One-Hot encode the 'InternetService' column
internetServ = house_df[['InternetService']]
ohe = OneHotEncoder()
InternetServ_encoded = ohe.fit_transform(internetServ).toarray()
feature_names = ohe.get_feature_names_out()

# Create a new DataFrame with the encoded data and concatenate it with the original DataFrame
InternetServ_encoded_float = InternetServ_encoded.astype('float64')
house_df_encoded = pd.DataFrame(InternetServ_encoded_float, columns=feature_names)
house_df = pd.concat([house_df, house_df_encoded], axis=1)

# Select features and labels
X = house_df[['MonthlyCharges'] + list(feature_names)]
y = house_df['Churn'].values

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Instantiate and fit the KNN model
knn = KNeighborsClassifier(n_neighbors=18)
knn.fit(X_train, y_train)

# Predict and evaluate the model
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.7321344060577378
# Confusion Matrix:
# [[1432  107]
#  [ 459  115]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.83      1539
#            1       0.52      0.20      0.29       574
#
#     accuracy                           0.73      2113
#    macro avg       0.64      0.57      0.56      2113
# weighted avg       0.69      0.73      0.69      2113

# %%
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

# Define the range of k values to test
k_values = range(1, 21)
# List to store cross-validation scores for each k
cv_scores = []

# Perform cross-validation for each k
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
    cv_scores.append(scores.mean())

# Find the k with the highest cross-validation score
optimal_k = k_values[cv_scores.index(max(cv_scores))]
print(f"The optimal number of neighbors is {optimal_k}")

# Plotting the cross-validation scores
plt.plot(k_values, cv_scores)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Cross-Validation Accuracy')
plt.title('Optimal K Selection')
plt.show()
# Out:
# The optimal number of neighbors is 18
